# %% [markdown]
# | Name            | UID       |
# |-----------------|-----------|
# | Huy Lai         | 132000359 |
# | Alex Nuccitelli | 000000000 |
# | Cole Jahnke     | 530009075 |
#
# 12 October 2021
# MATH 151-557

# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric)

# %% [markdown]
# # 1a Values of r which solve differential equation

# %%
x = symbols('x')
r = symbols('r')

y = exp(r * x)
dy = y.diff(x)
ddy = dy.diff(x)
solve(ddy + 5 * dy + 6 * y, r)
# Out:
# [-3, -2]

# %% [markdown]
# # 1b Values of r which solve differential equation

# %%
y = exp(r * x)
dy = y.diff(x)
ddy = dy.diff(x)
solve(ddy + 6 * dy + 13 * y, r)
# Out:
# [-3 - 2*I, -3 + 2*I]

# %% [markdown]
# # 1c Compute left hand side with cosines and sines and conclusion

# %%
y = exp(-3 * x) * (cos(2 * x) + sin(2 * x))
dy = y.diff(x)
ddy = dy.diff(x)
simplify(ddy + 6 * dy + 13 * y)

# e^(-3x)(cos(2x)+sin(2x)) is a solution to the differential equation
# Out:
# 0

# %% [markdown]
# # 2a Implicit Plot

# %%
matplotlib notebook

# %%
x = symbols('x', real=True)
y = symbols('y', real=True)
F = (x**2 + y**2)**2 - (4 * (x**2 - y**2)) + 3
Fplot = plot_implicit(F, (x, -3, 3),(y,-3,3))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 2b dy/dx

# %%
dydx = idiff(F, y, x)
print("The derivative of the function is", dydx)
# Out:
# The derivative of the function is x*(-x**2 - y**2 + 2)/(y*(x**2 + y**2 + 2))

# %% [markdown]
# # 2c Horizontal tangent lines

# %%
num = numer(dydx)
htan = solve([num, F],[x,y])
print("The horizontal tangents are", htan)
# Out:
# The horizontal tangents are [(-sqrt(30)/4, -sqrt(2)/4), (-sqrt(30)/4, sqrt(2)/4), (sqrt(30)/4, -sqrt(2)/4), (sqrt(30)/4, sqrt(2)/4)]

# %% [markdown]
# # 2d Tangent line equation at (sqrt(2), sqrt(sqrt(17)-4))

# %%
point = {x:sqrt(2), y:sqrt(sqrt(17) - 4)}
m = dydx.subs(point)
line = m * (x - point[x]) + point[y]
print("The tangent line equation is", line)
# Out:
# The tangent line equation is -sqrt(34)*sqrt(-4 + sqrt(17))*(x - sqrt(2))/17 + sqrt(-4 + sqrt(17))

# %% [markdown]
# # 2e Plot equation with tangent line in part (d)

# %%
matplotlib notebook

# %%
pcurve = plot_implicit(F, (x, -3, 3), (y, -3, 3),show=False)
pcurve.extend(plot(line, show=False))
pcurve.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3a (n+1)th derivative of x^n ln(x)

# %%
x = symbols('x')
n = symbols('n')
eq = x ** n * ln(x)
[simplify(eq.subs(n, i).diff(x, i)) for i in range(2, 9)]
# Out:
# [2*log(x) + 3,
#  6*log(x) + 11,
#  24*log(x) + 50,
#  120*log(x) + 274,
#  720*log(x) + 1764,
#  5040*log(x) + 13068,
#  40320*log(x) + 109584]

# %% [markdown]
# # 3b Conclusion

# %%
print("n!(ln(x) + 1 + 1/2 + ... + 1/n)")
# Out:
# n!(ln(x) + 1 + 1/2 + ... + 1/n)

# %% [markdown]
# # 4a Logarithmic Differentiation

# %%
x = symbols('x')
y = symbols('y')
q = sqrt(x) * log(x) - log(y)
simplify(idiff(q, y, x))
# Out:
# y*(log(x) + 2)/(2*sqrt(x))

# %% [markdown]
# # 4b Direct Differentiation

# %%
q = x**sqrt(x)
simplify(diff(q, x))
# Out:
# x**(sqrt(x) - 1/2)*(log(x) + 2)/2
