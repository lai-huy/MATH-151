# %% [markdown]
# | Name                 | UIN       |
# |----------------------|-----------|
# | Huy Lai              | 132000359 |
# | Alexander Nuccitelli | 000000000 |
# | Cole Jahnke          | 530009075 |
#
# MATH 151-557
# 02 November 2021

# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric)

# %% [markdown]
# # 1a Graph of piecewise function

# %%
matplotlib notebook

# %%
x = symbols('x')
f1 = 36 - x ** 2
f2 = 4 * x - 2
plot((f1, (x, -6, 0)), (f2, (x, 0, 6)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 1b Absolute max and min based on graph

# %%
print("The absolute maximum of f on [-6,6] is 22, which occurs at x=6")
print("The absolute minimum of f on [-6,6] is -2, which occurs at x=0")
# Out:
# The absolute maximum of f on [-6,6] is 22, which occurs at x=6
# The absolute minimum of f on [-6,6] is -2, which occurs at x=0

# %% [markdown]
# # 2a Critical values of f

# %%
x = symbols('x', real=True)
f = exp(x) + exp(-3 * x)
cvals = solve(f.diff(), x)
print(cvals)
print([i.evalf() for i in cvals])
# Out:
# [log(3**(1/4))]
# [0.274653072167027]

# %% [markdown]
# # 2b absolute max and min on [0,1]

# %%
candidates = [0, 1]
for val in cvals:
    if 0 <= val <= 1:
        candidates.append(val)

vals = []
for val in candidates:
    vals.append(f.subs(x, val))
print(max(vals).evalf())
print(min(vals).evalf())
# Out:
# 2.76806889682691
# 1.75476535060332

# %% [markdown]
# # 2c graphical confirmation of part b)

# %%
matplotlib notebook

# %%
plot(f, xlim=[0, 1], ylim=[0, 5])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3a Plot of f and apparent number of local extrema

# %%
matplotlib notebook

# %%
x = symbols('x')
f = sin(x + sin(3 * x))
plot(f, xlim=[0,2 * pi])
print("There are 7 local extrema")
# Out:
# <img src="data:image/png;base64,..." width="640">
# There are 7 local extrema

# %% [markdown]
# # 3b Derivative

# %%
fPrime = f.diff()
fPrime
# Out:
# (3*cos(3*x) + 1)*cos(x + sin(3*x))

# %% [markdown]
# # 3c Plot f' in [0.5, 0.7]

# %%
matplotlib notebook

# %%
plot(fPrime, xlim=[0.5,0.7], ylim=[-0.01,0.01])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3d Critical values in [0.5, 0.7]

# %%
point1 = nsolve(fPrime, .59)
point2 = nsolve(fPrime, .63)
point3 = nsolve(fPrime, .68)
print('The critical values are x =',point1,'x =', point2, 'x =',point3)
# Out:
# The critical values are x = 0.591429528804626 x = 0.636877745416340 x = 0.683070032340304

# %% [markdown]
# # 3e repeat parts (c) and (d) for the interval [5.5, 5.7]

# %%
matplotlib notebook

# %%
plot(fPrime, xlim=[5.5,5.7], ylim=[-0.01,0.01])
point1 = nsolve(fPrime, 5.59)
point2 = nsolve(fPrime, 5.63)
point3 = nsolve(fPrime, 5.68)
print('The critical values are x =',point1,'x =', point2, 'x =',point3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# The critical values are x = 5.60011527483928 x = 5.64630756176325 x = 5.69175577837496

# %% [markdown]
# # 3f Actual number of local extrema

# %%
print("Actually there are 12 local extrema because the regions at (.5 , .7) and (5.5, 5.7) have 3 local extrema not 1")
# Out:
# Actually there are 12 local extrema because the regions at (.5 , .7) and (5.5, 5.7) have 3 local extrema not 1

# %% [markdown]
# # 4a Two-variable function to be maximized and equation relating the two variables

# %%
s = symbols('s')
h= symbols('h')
SA = symbols('SA')
A = (s ** 2) + 4 * (h * s)
V = s * s * h
print(V)
print(A)
A = (s ** 2) + 4 * (h * s) - SA
# Out:
# h*s**2
# 4*h*s + s**2

# %% [markdown]
# # 4b Solve equation and substitute into function

# %%
height = solve(A, h)
V = V.subs(h, height[0])
print(V)
# Out:
# s*(SA - s**2)/4

# %% [markdown]
# # 4c practical domain

# %%
domains = solve(V, s)
print("The upper bound of the domain is",domains[2])
# Out:
# The upper bound of the domain is sqrt(SA)

# %% [markdown]
# # 4d Absolute maximum of function from part (b) on domain from part (c)

# %%
maxium = solve(V.diff(s), s)
print('The maxium side length is', V.subs(s, maxium[1]))
A = A.subs(s, maxium[1])
max_Height = solve(A, h)
print('The maxium height is', max_Height[0])
# Out:
# The maxium side length is sqrt(3)*SA**(3/2)/18
# The maxium height is sqrt(3)*sqrt(SA)/6
